# %% [markdown]
# ## importing library files for image processing

# %%
import skimage               # to install this package the command is:      conda install -c anaconda scikit-image
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from skimage import io                     # to read input and output

# %%
from skimage import data                   # set of images in data " https://scikit-image.org/docs/dev/auto_examples/index.html"

# %%
img = io.imread('flowers.jpg')     # load a image from system

# %%
plt.imshow(img)                   #display the image with x and y axis

# %%
img                           # to see the array of the image
# Out:
# array([[[255, 226, 156],
#         [255, 226, 156],
#         [255, 227, 153],
#         ...,
#         [250, 186,  86],
#         [247, 182,  80],
#         [243, 178,  74]],
#
#        [[255, 226, 156],
#         [255, 227, 154],
#         [255, 227, 153],
#         ...,
#         [255, 197,  95],
#         [255, 192,  89],
#         [251, 188,  85]],
#
#        [[254, 225, 155],
#         [254, 226, 153],
#         [255, 225, 152],
#         ...,
#         [255, 207, 106],
#         [255, 202, 102],
#         [255, 199,  97]],
#
#        ...,
#
#        [[ 46, 110,  23],
#         [ 46, 111,  21],
#         [ 47, 113,  16],
#         ...,
#         [120, 162,  96],
#         [ 98, 146,  86],
#         [ 87, 138,  81]],
#
#        [[ 45, 111,  23],
#         [ 46, 111,  21],
#         [ 47, 113,  16],
#         ...,
#         [115, 161,  96],
#         [ 97, 147,  88],
#         [ 88, 141,  87]],
#
#        [[ 44, 110,  22],
#         [ 47, 112,  22],
#         [ 48, 114,  17],
# ...

# %%
type(img)         # to see the type
# Out:
# numpy.ndarray

# %%
img.shape    # to check how many rows and columns in image (rows, Columns, Channels)
# Out:
# (638, 640, 3)

# %%
camera = data.camera()     # importing a image from data

# %%
camera                     # display the array matrix
# Out:
# array([[156, 157, 160, ..., 152, 152, 152],
#        [156, 157, 159, ..., 152, 152, 152],
#        [158, 157, 156, ..., 152, 152, 152],
#        ...,
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111]], dtype=uint8)

# %%
type(camera)         # to see the type
# Out:
# numpy.ndarray

# %%
plt.imshow(camera)
camera.shape             # to check how many rows and columns in image (rows, Columns, Channels)
# Out:
# (512, 512)

# %%
camera.size            #size of the image
# Out:
# 262144

# %%
plt.imshow(camera,'gray')            # display the image in gray

# %%
camera.max()                      # maximam intensity or pixel value
# Out:
# 255

# %%
camera.min()                      # minimum intensity or pixel value
# Out:
# 0

# %%
img.max()
# Out:
# 255

# %%
img.min()
# Out:
# 0

# %%
plt.imshow(img[:,:,1])         # Channel ( 0 - Red , 1- Green, 2 - Blue)

# %%
plt.imshow(img[:,:,0])          # Channel ( 0 - Red , 1- Green, 2 - Blue)

# %%
plt.imshow(img[:,:,2])          # Channel ( 0 - Red , 1- Green, 2 - Blue)

# %%
img[20,30]                # checking the particular pixel value, in this img is a coloured image
# Out:
# array([240, 195,  80], dtype=uint8)

# %%
camera = data.camera()           # loading a  new image named camera and intensity value of particular pixel is displayed
camera[10,20]
# Out:
# 153

# %%
camera[:,10] = 0                   # Assign value for all rows and 10 th column

# %%
plt.imshow(camera, 'gray')         # display the image

# %%
camera[10,:] = 0                        # Assign value for 10th row and all columns

# %%
plt.imshow(camera,'gray')

# %%
#Threshold
camera = data.camera()
mask = camera<87                 # in image the pixel values which ever lesser than 87 will be assigned 150
camera[mask] = 150
plt.imshow(camera,'gray')

# %%
#Threshold now i changed the assigned value to 255
camera = data.camera()
mask = camera<87                 # in image the pixel values which ever lesser than 87 will be assigned 150
camera[mask] = 255
plt.imshow(camera,'gray')

# %%
img1 = io.imread('flowers.jpg')

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (638, 640, 3)

# %%
img1[50,60]
# Out:
# array([204, 188, 126], dtype=uint8)

# %%
img1[50,60] = [0,255,0]      # it is a coloured image so [R,G,B] assigned to a particular pixel
plt.imshow(img1)

# %%
cat = data.chelsea()

# %%
red_cat = cat.copy()
mask = cat[:,:,0]>100
red_cat[mask] = [0,0,255]            # change the values so that you can get R, G & B  you will get image [R,G,B]
plt.imshow(red_cat)

# %%
red_cat = cat.copy()
mask = cat[:,:,0]>100
red_cat[mask] = [56,100,200]            # change the values so that you can get R, G & B  you will get image [R,G,B]
plt.imshow(red_cat)

# %%
BGR_cat = cat[:,:,::-1]              # to assing R value - B; G value - G and B value - R
plt.imshow(BGR_cat)

# %%
img4 = io.imread('C:/Users/hemac/Documents/my computer vision projects/cb.png')  # import the image even from anyother location

# %%
plt.imshow(img4)
